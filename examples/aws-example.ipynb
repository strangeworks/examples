# %%
import strangeworks
import strangeworks.qiskit

# %%
print(strangeworks.__version__)
print(strangeworks.qiskit.__version__)
# Out:
# 0.1.3
# 0.1.13

# %%
strangeworks.authenticate(username="", api_key="")

# %%
from qiskit import QuantumCircuit, execute
from strangeworks.qiskit.provider import StrangeworksProvider

# %%
provider = StrangeworksProvider()

# %%
# List available backends
provider.backends()
# Out:
# [aws.aws-managed.Aspen-11,
#  aws.aws-managed.IonQ Device,
#  azure.azure-managed.ionq.qpu,
#  azure.azure-managed.ionq.simulator,
#  azure.azure-managed.honeywell.hqs-lt-s1,
#  azure.azure-managed.honeywell.hqs-lt-s1-apival,
#  azure.azure-managed.honeywell.hqs-lt-s2,
#  azure.azure-managed.honeywell.hqs-lt-s2-apival,
#  azure.azure-managed.honeywell.hqs-lt-s1-sim,
#  ibm.ibm-test.strangeworks-hub.science-team.science-test.ibmq_qasm_simulator,
#  ibm.ibm-test.strangeworks-hub.science-team.science-test.ibmq_armonk,
#  ibm.ibm-test.strangeworks-hub.science-team.science-test.ibmq_montreal,
#  ibm.ibm-test.strangeworks-hub.science-team.science-test.ibmq_santiago,
#  ibm.ibm-test.strangeworks-hub.science-team.science-test.ibmq_lima,
#  ibm.ibm-test.strangeworks-hub.science-team.science-test.ibmq_belem,
#  ibm.ibm-test.strangeworks-hub.science-team.science-test.ibmq_quito,
#  ibm.ibm-test.strangeworks-hub.science-team.science-test.ibmq_manila,
# ...

# %%
# utilize Rigetti via AWS
# Make sure backend is in the list above
backend = provider.get_backend("aws.aws-managed.Aspen-11")

# %%
backend.status()
# Out:
# <pre>&lt;qiskit.providers.models.backendstatus.BackendStatus object at 0x10f5dd0a0&gt;</pre><b>name</b>: Aspen-11<br/><b>version</b>: , <b>pending jobs</b>: 0<br/><b>status</b>: <br/>

# %%
# reset result id
# strangeworks.client.result_id = ""

# %%
from qiskit import QuantumCircuit
qc = QuantumCircuit(2, 2)
qc.h(0)
qc.cx(0, 1)
qc.measure([0, 1], [0, 1])
qc.draw()
# Out:
#      ┌───┐     ┌─┐
# q_0: ┤ H ├──■──┤M├───
#      └───┘┌─┴─┐└╥┘┌─┐
# q_1: ─────┤ X ├─╫─┤M├
#           └───┘ ║ └╥┘
# c: 2/═══════════╩══╩═
#                 0  1

# %%
# execute a simple circuit
job = backend.run(qc, shots = 10)
print(job.job_id())
# Out:
# lonely-hail-9700

# %%
print(f"https://app.quantumcomputing.com/results/{strangeworks.client.result_id}")
# Out:
# https://app.quantumcomputing.com/results/b0382f2a-36cd-498a-8f60-1ff01ad18f1a

# %%
from strangeworks.qiskit.jobs.strangeworksjob import StrangeworksJob

# we can fetch old job results too, update with job ID from above
j = StrangeworksJob.get(job_id="lonely-hail-9700")
print(j.result().get_counts())
