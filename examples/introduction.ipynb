# %%
import strangeworks
import strangeworks.qiskit

# %% [markdown]
# ### First Things First, Authentication
#
# You must authenticate with our platform to utilize the Strangeworks SDK.
# We provide an authentication method that requires your username and an API token.
# Both your username and API token can be found at [settings page](https://app.quantumcomputing.com/settings).

# %%
strangeworks.authenticate(username, api_key)

# %%
print(strangeworks.__version__)
print(strangeworks.qiskit.__version__)
# Out:
# 0.2.15
# 0.3.6

# %% [markdown]
# ### StrangeworksProvider
#
# We implement our own `qiskit.providers.provider.ProviderV1`, called `StrangeworksProvider`.
# `StrangeworksProvider` gives you the expected functionality of a qiskit.ProviderV1.
#
# You can determine which backends are available to you through our platform. Check it out.

# %%
from strangeworks.qiskit import StrangeworksProvider
provider = StrangeworksProvider()

provider.backends()
# Out:
# [aws.aws-managed.Advantage_system4.1,
#  aws.aws-managed.Advantage_system6.1,
#  aws.aws-managed.Aspen-11,
#  aws.aws-managed.Aspen-M-1,
#  aws.aws-managed.Borealis,
#  aws.aws-managed.DW_2000Q_6,
#  aws.aws-managed.IonQ Device,
#  aws.aws-managed.Lucy,
#  aws.aws-managed.SV1,
#  aws.aws-managed.dm1,
#  azure.azure-managed.ionq.qpu,
#  azure.azure-managed.ionq.simulator,
#  azure.azure-managed.honeywell.hqs-lt-s1,
#  azure.azure-managed.honeywell.hqs-lt-s1-apival,
#  azure.azure-managed.honeywell.hqs-lt-s2,
#  azure.azure-managed.honeywell.hqs-lt-s2-apival,
#  azure.azure-managed.honeywell.hqs-lt-s1-sim,
#  ibm.ibm-cloud.ibm_algiers,
#  ibm.ibm-cloud.ibm_canberra,
#  ibm.ibm-managed.ibmq_qasm_simulator,
#  ibm.ibm-managed.ibmq_armonk,
#  ibm.ibm-managed.ibmq_santiago,
#  ibm.ibm-managed.ibmq_lima,
#  ibm.ibm-managed.ibmq_belem,
#  ibm.ibm-managed.ibmq_quito,
#  ibm.ibm-managed.ibmq_manila,
#  ibm.ibm-managed.ibm_nairobi,
#  ibm.ibm-test.strangeworks-hub.science-team.science-test.ibmq_qasm_simulator,
#  ibm.ibm-test.strangeworks-hub.science-team.science-test.ibmq_armonk,
#  ibm.ibm-test.strangeworks-hub.science-team.science-test.ibmq_santiago,
#  ibm.ibm-test.strangeworks-hub.science-team.science-test.ibmq_lima,
#  ibm.ibm-test.strangeworks-hub.science-team.science-test.ibmq_belem,
#  ibm.ibm-test.strangeworks-hub.science-team.science-test.ibmq_quito,
#  ibm.ibm-test.strangeworks-hub.science-team.science-test.ibmq_manila,
#  ibm.ibm-test.strangeworks-hub.science-team.science-test.ibm_nairobi,
#  ibm.ibm-test.ibm-q.open.main.ibmq_qasm_simulator,
#  ibm.ibm-test.ibm-q.open.main.ibmq_armonk,
#  ibm.ibm-test.ibm-q.open.main.ibmq_santiago,
#  ibm.ibm-test.ibm-q.open.main.ibmq_bogota,
#  ibm.ibm-test.ibm-q.open.main.ibmq_lima,
#  ibm.ibm-test.ibm-q.open.main.ibmq_belem,
#  ibm.ibm-test.ibm-q.open.main.ibmq_quito,
#  ibm.ibm-test.ibm-q.open.main.simulator_statevector,
#  ibm.ibm-test.ibm-q.open.main.simulator_mps,
#  ibm.ibm-test.ibm-q.open.main.simulator_extended_stabilizer,
#  ibm.ibm-test.ibm-q.open.main.simulator_stabilizer,
#  ibm.ibm-test.ibm-q.open.main.ibmq_manila,
#  rigetti.rigetti-managed.Aspen-11,
#  rigetti.rigetti-managed.Aspen-M-1,
#  rigetti.rigetti-managed.Aspen-11-qvm,
#  rigetti.rigetti-managed.Aspen-M-1-qvm,
#  rigetti.rigetti-managed.9q-square-qvm,
#  rigetti.rigetti-managed.9q-square-noisy-qvm,
#  ibm.strange-dylan.strangeworks-hub.science-team.science-test.ibmq_qasm_simulator,
#  ibm.strange-dylan.strangeworks-hub.science-team.science-test.ibmq_armonk,
#  ibm.strange-dylan.strangeworks-hub.science-team.science-test.ibmq_santiago,
#  ibm.strange-dylan.strangeworks-hub.science-team.science-test.ibmq_lima,
#  ibm.strange-dylan.strangeworks-hub.science-team.science-test.ibmq_belem,
#  ibm.strange-dylan.strangeworks-hub.science-team.science-test.ibmq_quito,
#  ibm.strange-dylan.strangeworks-hub.science-team.science-test.ibmq_manila,
#  ibm.strange-dylan.strangeworks-hub.science-team.science-test.ibm_nairobi,
#  ibm.strange-dylan.ibm-q.open.main.ibmq_qasm_simulator,
#  ibm.strange-dylan.ibm-q.open.main.ibmq_armonk,
#  ibm.strange-dylan.ibm-q.open.main.ibmq_santiago,
#  ibm.strange-dylan.ibm-q.open.main.ibmq_bogota,
#  ibm.strange-dylan.ibm-q.open.main.ibmq_lima,
#  ibm.strange-dylan.ibm-q.open.main.ibmq_belem,
#  ibm.strange-dylan.ibm-q.open.main.ibmq_quito,
#  ibm.strange-dylan.ibm-q.open.main.simulator_statevector,
#  ibm.strange-dylan.ibm-q.open.main.simulator_mps,
#  ibm.strange-dylan.ibm-q.open.main.simulator_extended_stabilizer,
#  ibm.strange-dylan.ibm-q.open.main.simulator_stabilizer,
#  ibm.strange-dylan.ibm-q.open.main.ibmq_manila,
#  ibm.strangeworks-ibm.ibmq_qasm_simulator,
#  ibm.strangeworks-ibm.ibmq_armonk,
#  ibm.strangeworks-ibm.ibmq_santiago,
#  ibm.strangeworks-ibm.ibmq_lima,
#  ibm.strangeworks-ibm.ibmq_belem,
#  ibm.strangeworks-ibm.ibmq_quito,
#  ibm.strangeworks-ibm.ibmq_manila,
#  ibm.strangeworks-ibm.ibm_nairobi,
#  ibm.unique-name-here.strangeworks-hub.qc-com.runtime.ibmq_qasm_simulator,
#  ibm.unique-name-here.strangeworks-hub.qc-com.runtime.ibm_nairobi,
#  ibm.unique-name-here.strangeworks-hub.science-team.science-test.ibmq_qasm_simulator,
#  ibm.unique-name-here.strangeworks-hub.science-team.science-test.ibmq_armonk,
#  ibm.unique-name-here.strangeworks-hub.science-team.science-test.ibmq_santiago,
#  ibm.unique-name-here.strangeworks-hub.science-team.science-test.ibmq_lima,
#  ibm.unique-name-here.strangeworks-hub.science-team.science-test.ibmq_belem,
#  ibm.unique-name-here.strangeworks-hub.science-team.science-test.ibmq_quito,
#  ibm.unique-name-here.strangeworks-hub.science-team.science-test.ibmq_manila,
#  ibm.unique-name-here.strangeworks-hub.science-team.science-test.ibm_nairobi,
#  ibm.unique-name-here.ibm-q.open.main.ibmq_qasm_simulator,
#  ibm.unique-name-here.ibm-q.open.main.ibmq_armonk,
#  ibm.unique-name-here.ibm-q.open.main.ibmq_santiago,
#  ibm.unique-name-here.ibm-q.open.main.ibmq_bogota,
#  ibm.unique-name-here.ibm-q.open.main.ibmq_lima,
#  ibm.unique-name-here.ibm-q.open.main.ibmq_belem,
#  ibm.unique-name-here.ibm-q.open.main.ibmq_quito,
#  ibm.unique-name-here.ibm-q.open.main.simulator_statevector,
#  ibm.unique-name-here.ibm-q.open.main.simulator_mps,
#  ibm.unique-name-here.ibm-q.open.main.simulator_extended_stabilizer,
#  ibm.unique-name-here.ibm-q.open.main.simulator_stabilizer,
#  ibm.unique-name-here.ibm-q.open.main.ibmq_manila,
#  aer_simulator,
#  aer_simulator_statevector,
#  aer_simulator_density_matrix,
#  aer_simulator_stabilizer,
#  aer_simulator_matrix_product_state,
#  aer_simulator_extended_stabilizer,
#  aer_simulator_unitary,
#  aer_simulator_superop,
#  qasm_simulator,
#  statevector_simulator,
#  unitary_simulator,
#  pulse_simulator]

# %% [markdown]
# ### Backend Name
# As you can see above, I have multiple available backends.
# When requesting a backend from our provider, you must utilize one of the names listed above.
# The backend name usually follows the convention of provider-id.your-account-unique-code-id.backend-name.
#
# `your-account-unique-code-id` is the UNIQUE CODE ID displayed in your accounts page. For example you can view your IBM accounts [here](https://app.quantumcomputing.com/hardware/ibm/accounts).
#
# Let me request a Strangeworks managed IBM backend.

# %%
hw = provider.get_backend("ibm.ibm-managed.ibmq_quito")

name = hw.name()
status = hw.status()
properties = hw.properties()
print(f"{name} status: {status.to_dict()}")
if properties:
    print(f"{name} properties: \n{properties.to_dict()}")
# Out:
# ibm.ibm-managed.ibmq_quito status: {'backend_name': 'ibmq_quito', 'backend_version': '1.1.30', 'operational': True, 'pending_jobs': 678, 'status_msg': 'active'}
# ibm.ibm-managed.ibmq_quito properties:
# {'backend_name': 'ibmq_quito', 'backend_version': '1.1.30', 'last_update_date': datetime.datetime(2022, 6, 12, 5, 15, 58, tzinfo=tzutc()), 'qubits': [[{'date': '2022-06-12T04:17:13Z', 'name': 'T1', 'unit': 'us', 'value': 79.18562330656808}, {'date': '2022-06-12T04:20:00Z', 'name': 'T2', 'unit': 'us', 'value': 126.7805829212059}, {'date': '2022-06-12T05:15:58Z', 'name': 'frequency', 'unit': 'GHz', 'value': 5.300544609070768}, {'date': '2022-06-12T05:15:58Z', 'name': 'anharmonicity', 'unit': 'GHz', 'value': -0.3314801694030778}, {'date': '2022-06-12T04:12:10Z', 'name': 'readout_error', 'unit': '', 'value': 0.03810000000000002}, {'date': '2022-06-12T04:12:10Z', 'name': 'prob_meas0_prep1', 'unit': '', 'value': 0.059799999999999964}, {'date': '2022-06-12T04:12:10Z', 'name': 'prob_meas1_prep0', 'unit': '', 'value': 0.0164}, {'date': '2022-06-12T04:12:10Z', 'name': 'readout_length', 'unit': 'ns', 'value': 5351.11111111111}], [{'date': '2022-06-12T04:17:13Z', 'name': 'T1', 'unit': 'us', 'value': 117.96348876430677}, {'date': '2022-06-12T04:25:35Z', 'name': 'T2', 'unit': 'us', 'value': 132.39670733567837}, {'date': '2022-06-12T05:15:58Z', 'name': 'frequency', 'unit': 'GHz', 'value': 5.080581125014044}, {'date': '2022-06-12T05:15:58Z', 'name': 'anharmonicity', 'unit': 'GHz', 'value': -0.3192453770191231}, {'date': '2022-06-12T04:12:10Z', 'name': 'readout_error', 'unit': '', 'value': 0.041100000000000025}, {'date': '2022-06-12T04:12:10Z', 'name': 'prob_meas0_prep1', 'unit': '', 'value': 0.05620000000000003}, {'date': '2022-06-12T04:12:10Z', 'name': 'prob_meas1_prep0', 'unit': '', 'value': 0.026}, {'date': '2022-06-12T04:12:10Z', 'name': 'readout_length', 'unit': 'ns', 'value': 5351.11111111111}], [{'date': '2022-06-12T03:50:28Z', 'name': 'T1', 'unit': 'us', 'value': 95.78884581833306}, {'date': '2022-06-12T04:20:00Z', 'name': 'T2', 'unit': 'us', 'value': 115.85642184453066}, {'date': '2022-06-12T05:15:58Z', 'name': 'frequency', 'unit': 'GHz', 'value': 5.322189060588371}, {'date': '2022-06-12T05:15:58Z', 'name': 'anharmonicity', 'unit': 'GHz', 'value': -0.33231656282971167}, {'date': '2022-06-12T04:12:10Z', 'name': 'readout_error', 'unit': '', 'value': 0.0717000000000001}, {'date': '2022-06-12T04:12:10Z', 'name': 'prob_meas0_prep1', 'unit': '', 'value': 0.07220000000000004}, {'date': '2022-06-12T04:12:10Z', 'name': 'prob_meas1_prep0', 'unit': '', 'value': 0.0712}, {'date': '2022-06-12T04:12:10Z', 'name': 'readout_length', 'unit': 'ns', 'value': 5351.11111111111}], [{'date': '2022-06-12T04:17:13Z', 'name': 'T1', 'unit': 'us', 'value': 107.55192325306693}, {'date': '2022-06-12T04:20:00Z', 'name': 'T2', 'unit': 'us', 'value': 22.825391726942293}, {'date': '2022-06-12T05:15:58Z', 'name': 'frequency', 'unit': 'GHz', 'value': 5.163606035349068}, {'date': '2022-06-12T05:15:58Z', 'name': 'anharmonicity', 'unit': 'GHz', 'value': -0.33508064939515236}, {'date': '2022-06-12T04:12:10Z', 'name': 'readout_error', 'unit': '', 'value': 0.03410000000000002}, {'date': '2022-06-12T04:12:10Z', 'name': 'prob_meas0_prep1', 'unit': '', 'value': 0.05479999999999996}, {'date': '2022-06-12T04:12:10Z', 'name': 'prob_meas1_prep0', 'unit': '', 'value': 0.0134}, {'date': '2022-06-12T04:12:10Z', 'name': 'readout_length', 'unit': 'ns', 'value': 5351.11111111111}], [{'date': '2022-06-12T04:17:13Z', 'name': 'T1', 'unit': 'us', 'value': 92.2665259353799}, {'date': '2022-06-12T04:25:35Z', 'name': 'T2', 'unit': 'us', 'value': 110.84332328454333}, {'date': '2022-06-12T05:15:58Z', 'name': 'frequency', 'unit': 'GHz', 'value': 5.05232174642549}, {'date': '2022-06-12T05:15:58Z', 'name': 'anharmonicity', 'unit': 'GHz', 'value': -0.3192628614050085}, {'date': '2022-06-12T04:12:10Z', 'name': 'readout_error', 'unit': '', 'value': 0.03620000000000001}, {'date': '2022-06-12T04:12:10Z', 'name': 'prob_meas0_prep1', 'unit': '', 'value': 0.05300000000000005}, {'date': '2022-06-12T04:12:10Z', 'name': 'prob_meas1_prep0', 'unit': '', 'value': 0.0194}, {'date': '2022-06-12T04:12:10Z', 'name':  ...

# %%
from qiskit import QuantumCircuit

qc = QuantumCircuit(2, 2)
qc.h(0)
qc.cx(0, 1)
qc.measure([0, 1], [0, 1])

qasm_sim = provider.get_backend("ibm.strangeworks-ibm.ibmq_qasm_simulator")
job = qasm_sim.run(qc, shots=50)
# job_id() corresponds to the job name displayed here https://app.quantumcomputing.com/jobs
print(f"{job.job_id()}")

# %%
job.status()

# %%
results = job.result()
print(f"results: {results}")
counts = results.get_counts()
print(f"counts: {counts}")

# %% [markdown]
# ### StrangeworksJob
#
# `StrangeworksJob` allows you to fetch any of your prior jobs!
# You just need to rember your job name. You can find job names [here](https://app.quantumcomputing.com/jobs).

# %%
from strangeworks.qiskit import StrangeworksJob

job = StrangeworksJob.get("bitter-reed-1698") ## Update this with your job ID
print(f"Status: {job.status()}")
job.result()
