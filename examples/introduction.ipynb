# %% [markdown]
# ### First Things First, Authentication
#
# You must authenticate with our platform to utilize the Strangeworks SDK.
# We provide an authentication method that requires your username and an API token.
# Both your username and API token can be found at [settings page](https://app.quantumcomputing.com/settings).

# %%
import strangeworks

strangeworks.authenticate(username="", api_key="")

# %% [markdown]
# ### StrangeworksProvider
#
# We implement our own `qiskit.providers.provider.ProviderV1`, called `StrangeworksProvider`.
# `StrangeworksProvider` gives you the expected functionality of a qiskit.ProviderV1.
#
# You can determine which backends are available to you through our platform. Check it out.

# %%
from strangeworks.qiskit import StrangeworksProvider
provider = StrangeworksProvider()

provider.backends()
# Out:
# [ibm.my-acct-unique-code-id.strangeworks-hub.qc-com.runtime.ibmq_qasm_simulator,
#  ibm.my-acct-unique-code-id.strangeworks-hub.qc-com.runtime.ibm_nairobi,
#  ibm.my-acct-unique-code-id.ibm-q.open.main.ibmq_qasm_simulator,
#  ibm.my-acct-unique-code-id.ibm-q.open.main.ibmq_armonk,
#  ibm.my-acct-unique-code-id.ibm-q.open.main.ibmq_santiago,
#  ibm.my-acct-unique-code-id.ibm-q.open.main.ibmq_bogota,
#  ibm.my-acct-unique-code-id.ibm-q.open.main.ibmq_lima,
#  ibm.my-acct-unique-code-id.ibm-q.open.main.ibmq_belem,
#  ibm.my-acct-unique-code-id.ibm-q.open.main.ibmq_quito,
#  ibm.my-acct-unique-code-id.ibm-q.open.main.simulator_statevector,
#  ibm.my-acct-unique-code-id.ibm-q.open.main.simulator_mps,
#  ibm.my-acct-unique-code-id.ibm-q.open.main.simulator_extended_stabilizer,
#  ibm.my-acct-unique-code-id.ibm-q.open.main.simulator_stabilizer,
#  ibm.my-acct-unique-code-id.ibm-q.open.main.ibmq_manila,
#  azure.strangeworks-azure.ionq.qpu,
#  azure.strangeworks-azure.ionq.simulator,
#  azure.strangeworks-azure.honeywell.hqs-lt-s1,
#  azure.strangeworks-azure.honeywell.hqs-lt-s1-apival,
#  azure.strangeworks-azure.honeywell.hqs-lt-s2,
#  azure.strangeworks-azure.honeywell.hqs-lt-s2-apival,
#  azure.strangeworks-azure.honeywell.hqs-lt-s1-sim,
#  ibm.strangeworks-ibm.ibmq_qasm_simulator,
#  ibm.strangeworks-ibm.ibmq_armonk,
#  ibm.strangeworks-ibm.ibmq_montreal,
#  ibm.strangeworks-ibm.ibmq_santiago,
#  ibm.strangeworks-ibm.ibmq_lima,
#  ibm.strangeworks-ibm.ibmq_belem,
#  ibm.strangeworks-ibm.ibmq_quito,
#  ibm.strangeworks-ibm.ibmq_manila,
#  ibm.strangeworks-ibm.ibm_nairobi,
#  aer_simulator,
#  aer_simulator_statevector,
#  aer_simulator_density_matrix,
#  aer_simulator_stabilizer,
#  aer_simulator_matrix_product_state,
#  aer_simulator_extended_stabilizer,
#  aer_simulator_unitary,
#  aer_simulator_superop,
#  qasm_simulator,
#  statevector_simulator,
#  unitary_simulator,
#  pulse_simulator]

# %% [markdown]
# ### Backend Name
# As you can see above, I have multiple available backends.
# When requesting a backend from our provider, you must utilize one of the names listed above.
# The backend name usually follows the convention of provider-id.your-account-unique-code-id.backend-name.
#
# `your-account-unique-code-id` is the UNIQUE CODE ID displayed in your accounts page. For example you can view your IBM accounts [here](https://app.quantumcomputing.com/hardware/ibm/accounts).
#
# Let me request a Strangeworks managed IBM backend.

# %%
santi = provider.get_backend("ibm.strangeworks-ibm.ibmq_santiago")

name = santi.name()
status = santi.status()
properties = santi.properties()
print(f"{name} status: {status.to_dict()}")
if properties:
    print(f"{name} properties: \n{properties.to_dict()}")
# Out:
# ibm.strangeworks-ibm.ibmq_santiago status: {'backend_name': 'ibmq_santiago', 'backend_version': '1.3.37', 'operational': True, 'pending_jobs': 371, 'status_msg': 'internal'}
# ibm.strangeworks-ibm.ibmq_santiago properties:
# {'backend_name': 'ibmq_santiago', 'backend_version': '1.3.37', 'last_update_date': datetime.datetime(2021, 11, 1, 18, 10, 21, tzinfo=tzutc()), 'qubits': [[{'date': '2021-11-01T16:01:11Z', 'name': 'T1', 'unit': 'us', 'value': 95.20831388721705}, {'date': '2021-11-01T04:11:57Z', 'name': 'T2', 'unit': 'us', 'value': 147.00040010475874}, {'date': '2021-11-01T18:10:21Z', 'name': 'frequency', 'unit': 'GHz', 'value': 4.833433684302573}, {'date': '2021-11-01T18:10:21Z', 'name': 'anharmonicity', 'unit': 'GHz', 'value': -0.3418851655730886}, {'date': '2021-11-01T04:10:39Z', 'name': 'readout_error', 'unit': '', 'value': 0.0129999999999999}, {'date': '2021-11-01T04:10:39Z', 'name': 'prob_meas0_prep1', 'unit': '', 'value': 0.0176}, {'date': '2021-11-01T04:10:39Z', 'name': 'prob_meas1_prep0', 'unit': '', 'value': 0.008399999999999963}, {'date': '2021-11-01T04:10:39Z', 'name': 'readout_length', 'unit': 'ns', 'value': 4017.7777777777774}], [{'date': '2021-11-01T04:11:26Z', 'name': 'T1', 'unit': 'us', 'value': 77.73450377438883}, {'date': '2021-11-01T04:12:55Z', 'name': 'T2', 'unit': 'us', 'value': 88.57872451198544}, {'date': '2021-11-01T18:10:21Z', 'name': 'frequency', 'unit': 'GHz', 'value': 4.623624534484714}, {'date': '2021-11-01T18:10:21Z', 'name': 'anharmonicity', 'unit': 'GHz', 'value': -0.3282321647779994}, {'date': '2021-11-01T04:10:39Z', 'name': 'readout_error', 'unit': '', 'value': 0.021400000000000086}, {'date': '2021-11-01T04:10:39Z', 'name': 'prob_meas0_prep1', 'unit': '', 'value': 0.032200000000000006}, {'date': '2021-11-01T04:10:39Z', 'name': 'prob_meas1_prep0', 'unit': '', 'value': 0.0106}, {'date': '2021-11-01T04:10:39Z', 'name': 'readout_length', 'unit': 'ns', 'value': 4017.7777777777774}], [{'date': '2021-11-01T04:11:26Z', 'name': 'T1', 'unit': 'us', 'value': 5.662868709274044}, {'date': '2021-10-16T04:10:07Z', 'name': 'T2', 'unit': 'us', 'value': 18.337714793481656}, {'date': '2021-11-01T18:10:21Z', 'name': 'frequency', 'unit': 'GHz', 'value': 4.818821092808912}, {'date': '2021-11-01T18:10:21Z', 'name': 'anharmonicity', 'unit': 'GHz', 'value': -0.34106631369543905}, {'date': '2021-11-01T04:10:39Z', 'name': 'readout_error', 'unit': '', 'value': 0.19019999999999992}, {'date': '2021-11-01T04:10:39Z', 'name': 'prob_meas0_prep1', 'unit': '', 'value': 0.3378}, {'date': '2021-11-01T04:10:39Z', 'name': 'prob_meas1_prep0', 'unit': '', 'value': 0.0426}, {'date': '2021-11-01T04:10:39Z', 'name': 'readout_length', 'unit': 'ns', 'value': 4017.7777777777774}], [{'date': '2021-11-01T16:04:09Z', 'name': 'T1', 'unit': 'us', 'value': 118.42915204633512}, {'date': '2021-11-01T04:12:55Z', 'name': 'T2', 'unit': 'us', 'value': 86.79593101342202}, {'date': '2021-11-01T18:10:21Z', 'name': 'frequency', 'unit': 'GHz', 'value': 4.742321542676422}, {'date': '2021-11-01T18:10:21Z', 'name': 'anharmonicity', 'unit': 'GHz', 'value': -0.3401329313955271}, {'date': '2021-11-01T04:10:39Z', 'name': 'readout_error', 'unit': '', 'value': 0.007000000000000006}, {'date': '2021-11-01T04:10:39Z', 'name': 'prob_meas0_prep1', 'unit': '', 'value': 0.009600000000000053}, {'date': '2021-11-01T04:10:39Z', 'name': 'prob_meas1_prep0', 'unit': '', 'value': 0.0044}, {'date': '2021-11-01T04:10:39Z', 'name': 'readout_length', 'unit': 'ns', 'value': 4017.7777777777774}], [{'date': '2021-11-01T04:11:26Z', 'name': 'T1', 'unit': 'us', 'value': 101.11786268853359}, {'date': '2021-11-01T04:11:57Z', 'name': 'T2', 'unit': 'us', 'value': 165.69533002492463}, {'date': '2021-11-01T18:10:21Z', 'name': 'frequency', 'unit': 'GHz', 'value': 4.816333203698816}, {'date': '2021-11-01T18:10:21Z', 'name': 'anharmonicity', 'unit': 'GHz', 'value': -0.342914680869458}, {'date': '2021-11-01T04:10:39Z', 'name': 'readout_error', 'unit': '', 'value': 0.016199999999999992}, {'date': '2021-11-01T04:10:39Z', 'name': 'prob_meas0_prep1', 'unit': '', 'value': 0.022599999999999953}, {'date': '2021-11-01T04:10:39Z', 'name': 'prob_meas1_prep0', 'unit': '', 'value': 0.0098}, {'date': '2021-11-01T04:10:39Z', 'nam ...

# %%
from qiskit import QuantumCircuit

qc = QuantumCircuit(2, 2)
qc.h(0)
qc.cx(0, 1)
qc.measure([0, 1], [0, 1])

qasm_sim = provider.get_backend("ibm.strangeworks-ibm.ibmq_qasm_simulator")
job1 = qasm_sim.run(qc, shots=50)
# job_id() corresponds to the job name displayed here https://app.quantumcomputing.com/jobs
print(f"{job1.job_id()}")
# Out:
# bitter-reed-1698

# %%
job1.status()
# Out:
# <JobStatus.INITIALIZING: 'job is being initialized'>

# %%
results = job1.result()
print(f"results: {results}")
counts = results.get_counts()
print(f"counts: {counts}")
# Out:
# results: Result(backend_name='ibmq_qasm_simulator', backend_version='0.9.1', qobj_id='eb78f8a5-be14-4157-94f8-48a1e4625f48', job_id='61803568982fa5b4693c6a0a', success=True, results=[ExperimentResult(shots=50, success=True, meas_level=2, data=ExperimentResultData(counts={'0x0': 27, '0x3': 23}), header=QobjExperimentHeader(clbit_labels=[['c', 0], ['c', 1]], creg_sizes=[['c', 2]], global_phase=0, memory_slots=2, metadata={}, n_qubits=2, name='circuit-5', qreg_sizes=[['q', 2]], qubit_labels=[['q', 0], ['q', 1]]), status=DONE, metadata={'active_input_qubits': [0, 1], 'device': 'CPU', 'fusion': {'enabled': False}, 'input_qubit_map': [[1, 1], [0, 0]], 'measure_sampling': True, 'method': 'stabilizer', 'noise': 'ideal', 'num_clbits': 2, 'num_qubits': 2, 'parallel_shots': 1, 'parallel_state_update': 16, 'remapped_qubits': False}, seed_simulator=2309739495, time_taken=0.00035564200000000003)], date=2021-11-01T18:43:56.502457, status=COMPLETED, status=QobjHeader(backend_name='ibmq_qasm_simulator', backend_version='0.1.547'), metadata={'max_gpu_memory_mb': 0, 'max_memory_mb': 386975, 'mpi_rank': 0, 'num_mpi_processes': 1, 'omp_enabled': True, 'parallel_experiments': 1, 'time_taken': 0.000667474}, time_taken=0.000667474)
# counts: {'00': 27, '11': 23}

# %% [markdown]
# ### StrangeworksJob
#
# `StrangeworksJob` allows you to fetch any of your prior jobs!
# You just need to rember your job name. You can find job names [here](https://app.quantumcomputing.com/jobs).

# %%
from strangeworks.qiskit import StrangeworksJob

job = StrangeworksJob.get("bitter-reed-1698")
print(f"Status: {job.status()}")
job.result()
# Out:
# Status: JobStatus.DONE
# Result(backend_name='ibmq_qasm_simulator', backend_version='0.9.1', qobj_id='eb78f8a5-be14-4157-94f8-48a1e4625f48', job_id='61803568982fa5b4693c6a0a', success=True, results=[ExperimentResult(shots=50, success=True, meas_level=2, data=ExperimentResultData(counts={'0x0': 27, '0x3': 23}), header=QobjExperimentHeader(clbit_labels=[['c', 0], ['c', 1]], creg_sizes=[['c', 2]], global_phase=0, memory_slots=2, metadata={}, n_qubits=2, name='circuit-5', qreg_sizes=[['q', 2]], qubit_labels=[['q', 0], ['q', 1]]), status=DONE, metadata={'active_input_qubits': [0, 1], 'device': 'CPU', 'fusion': {'enabled': False}, 'input_qubit_map': [[1, 1], [0, 0]], 'measure_sampling': True, 'method': 'stabilizer', 'noise': 'ideal', 'num_clbits': 2, 'num_qubits': 2, 'parallel_shots': 1, 'parallel_state_update': 16, 'remapped_qubits': False}, seed_simulator=2309739495, time_taken=0.00035564200000000003)], date=2021-11-01T18:43:56.502457, status=COMPLETED, status=QobjHeader(backend_name='ibmq_qasm_simulator', backend_version='0.1.547'), metadata={'max_gpu_memory_mb': 0, 'max_memory_mb': 386975, 'mpi_rank': 0, 'num_mpi_processes': 1, 'omp_enabled': True, 'parallel_experiments': 1, 'time_taken': 0.000667474}, time_taken=0.000667474)

# %%
# a url to download your results
job.strangeworks_result_url()
# Out:
# 'https://api.isstrange.com/jobs/2e78fb32-de3c-4881-8435-7b08e6585d4c/download'
