# %%
import strangeworks

# %%
strangeworks.__version__
# Out:
# '0.1.2'

# %%
strangeworks.authenticate(username="", api_key="")

# %%
from qiskit import QuantumCircuit, execute
from strangeworks.qiskit.provider import StrangeworksProvider

# %%
provider = StrangeworksProvider()

# %%
# the backend name comes from provider.backends()
backend = provider.get_backend("ibm.strangeworks-ibm.ibm_nairobi")

# %%
backend.status()
# Out:
# <pre>&lt;qiskit.providers.models.backendstatus.BackendStatus object at 0x7fbc8ee21be0&gt;</pre><b>name</b>: ibm_nairobi<br/><b>version</b>: 1, <b>pending jobs</b>: 0<br/><b>status</b>: <br/>

# %%
# reset result id
# strangeworks.client.result_id = ""

# %%
qc = QuantumCircuit(2, 2)
qc.h(0)
qc.cx(0, 1)
qc.measure([0, 1], [0, 1])
qc.draw()
# Out:
#      ┌───┐     ┌─┐
# q_0: ┤ H ├──■──┤M├───
#      └───┘┌─┴─┐└╥┘┌─┐
# q_1: ─────┤ X ├─╫─┤M├
#           └───┘ ║ └╥┘
# c: 2/═══════════╩══╩═
#                 0  1

# %%
job = execute(qc, backend, shots=50)

# %%
print(f"https://app.quantumcomputing.com/results/{strangeworks.client.result_id}")
# Out:
# https://app.quantumcomputing.com/results/f3c90cef-5ad6-4f8b-84eb-a951814c744c
